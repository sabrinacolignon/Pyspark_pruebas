# %% [markdown]
# # Importo librerías a utilizar #

# %%
import pyspark
from pyspark.sql import SparkSession

from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row

# %% [markdown]
# # Inicializo una SparkSession #

# %% [raw]
# Las aplicaciones PySpark comienzan con la inicialización de SparkSession, que es el punto de entrada de PySpark como se muestra a continuación. En caso de ejecutarlo en PySpark Shell a través del ejecutable pyspark, el Shell crea automáticamente la sesión en la variable Spark para los usuarios.

# %%
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# # Creo DataFrames de distintos métodos #

# %% [raw]
# Se puede crear un DataFrame de PySpark a través de pyspark.sql.SparkSession.createDataFrame, generalmente pasando una lista de listas, tuplas, diccionarios y pyspark.sql.Rows, un DataFrame de pandas y un RDD que consiste en dicha lista. pyspark.sql.SparkSession.createDataFrame toma el argumento de esquema para especificar el esquema del DataFrame. Cuando se omite, PySpark infiere el esquema correspondiente tomando una muestra de los datos.

# %% [raw]
# En primer lugar, puede crear un PySpark DataFrame a partir de una lista de filas.

# %%
df = spark.createDataFrame([
    Row(a=1, b=2., c='string1', d=date(2000, 1, 1), e=datetime(2000, 1, 1, 12, 0)),
    Row(a=2, b=3., c='string2', d=date(2000, 2, 1), e=datetime(2000, 1, 2, 12, 0)),
    Row(a=4, b=5., c='string3', d=date(2000, 3, 1), e=datetime(2000, 1, 3, 12, 0))
])
df
# Out:
# DataFrame[a: bigint, b: double, c: string, d: date, e: timestamp]

# %% [raw]
# Cree un PySpark DataFrame con un esquema explícito.

# %%
df = spark.createDataFrame([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
], schema='a long, b double, c string, d date, e timestamp')
df
# Out:
# DataFrame[a: bigint, b: double, c: string, d: date, e: timestamp]

# %% [raw]
# Cree un PySpark DataFrame a partir de un DataFrame de pandas

# %%
pandas_df = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [2., 3., 4.],
    'c': ['string1', 'string2', 'string3'],
    'd': [date(2000, 1, 1), date(2000, 2, 1), date(2000, 3, 1)],
    'e': [datetime(2000, 1, 1, 12, 0), datetime(2000, 1, 2, 12, 0), datetime(2000, 1, 3, 12, 0)]
})
df = spark.createDataFrame(pandas_df)
df
# Out:
# DataFrame[a: bigint, b: double, c: string, d: date, e: timestamp]

# %% [raw]
# Cree un PySpark DataFrame a partir de un RDD que consta de una lista de tuplas.

# %%
rdd = spark.sparkContext.parallelize([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
])
df = spark.createDataFrame(rdd, schema=['a', 'b', 'c', 'd', 'e'])
df
# Out:
# DataFrame[a: bigint, b: double, c: string, d: date, e: timestamp]

# %% [raw]
# Los DataFrames creados anteriormente tienen todos los mismos resultados y esquema.

# %%
df.show()
df.printSchema()
# Out:
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|
# |  2|3.0|string2|2000-02-01|2000-01-02 12:00:00|
# |  3|4.0|string3|2000-03-01|2000-01-03 12:00:00|
# +---+---+-------+----------+-------------------+
#
# root
#  |-- a: long (nullable = true)
#  |-- b: double (nullable = true)
#  |-- c: string (nullable = true)
#  |-- d: date (nullable = true)
#  |-- e: timestamp (nullable = true)

# %% [markdown]
# # Visualización de los datos #

# %% [raw]
# Las filas superiores de un DataFrame se pueden mostrar usando DataFrame.show().

# %%
df.show(1)
# Out:
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|
# +---+---+-------+----------+-------------------+
# only showing top 1 row

# %% [markdown]
# Como alternativa, puede habilitar la configuración spark.sql.repl.eagerEval.enabled para la evaluación diligente de PySpark DataFrame en notebooks como Jupyter. La cantidad de filas que se mostrarán se puede controlar mediante la configuración spark.sql.repl.eagerEval.maxNumRows.

# %%
spark.conf.set('spark.sql.repl.eagerEval.enabled', True)
df
# Out:
# DataFrame[a: bigint, b: double, c: string, d: date, e: timestamp]

# %% [raw]
# Las filas también se pueden mostrar verticalmente. Esto resulta útil cuando las filas son demasiado largas para mostrarse horizontalmente.

# %%
df.show(1, vertical=True)
# Out:
# -RECORD 0------------------
#  a   | 1
#  b   | 2.0
#  c   | string1
#  d   | 2000-01-01
#  e   | 2000-01-01 12:00:00
# only showing top 1 row

# %% [raw]
# Puede ver el esquema y los nombres de las columnas del DataFrame de la siguiente manera:

# %%
df.columns
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
df.printSchema()
# Out:
# root
#  |-- a: long (nullable = true)
#  |-- b: double (nullable = true)
#  |-- c: string (nullable = true)
#  |-- d: date (nullable = true)
#  |-- e: timestamp (nullable = true)

# %% [raw]
# Mostrar el resumen del DataFrame

# %%
df.select("a", "b", "c").describe().show()
# Out:
# +-------+---+---+-------+
# |summary|  a|  b|      c|
# +-------+---+---+-------+
# |  count|  3|  3|      3|
# |   mean|2.0|3.0|   NULL|
# | stddev|1.0|1.0|   NULL|
# |    min|  1|2.0|string1|
# |    max|  3|4.0|string3|
# +-------+---+---+-------+

# %% [raw]
# DataFrame.collect() recopila los datos distribuidos en el lado del controlador como datos locales en Python. Tenga en cuenta que esto puede generar un error de falta de memoria cuando el conjunto de datos es demasiado grande para caber en el lado del controlador, ya que recopila todos los datos de los ejecutores en el lado del controlador.

# %%
df.collect()
# Out:
# [Row(a=1, b=2.0, c='string1', d=datetime.date(2000, 1, 1), e=datetime.datetime(2000, 1, 1, 12, 0)),
#  Row(a=2, b=3.0, c='string2', d=datetime.date(2000, 2, 1), e=datetime.datetime(2000, 1, 2, 12, 0)),
#  Row(a=3, b=4.0, c='string3', d=datetime.date(2000, 3, 1), e=datetime.datetime(2000, 1, 3, 12, 0))]

# %% [raw]
# Para evitar generar una excepción de falta de memoria, use DataFrame.take() o DataFrame.tail().

# %%
df.take(1)
# Out:
# [Row(a=1, b=2.0, c='string1', d=datetime.date(2000, 1, 1), e=datetime.datetime(2000, 1, 1, 12, 0))]

# %% [raw]
# PySpark DataFrame también permite la conversión a un DataFrame de pandas para aprovechar la API de pandas. Tenga en cuenta que toPandas también recopila todos los datos en el lado del controlador, lo que puede provocar fácilmente un error de falta de memoria cuando los datos son demasiado grandes para caber en el lado del controlador.

# %%
df.toPandas()
# Out:
#    a    b        c           d                   e
# 0  1  2.0  string1  2000-01-01 2000-01-01 12:00:00
# 1  2  3.0  string2  2000-02-01 2000-01-02 12:00:00
# 2  3  4.0  string3  2000-03-01 2000-01-03 12:00:00

# %% [markdown]
# # Seleccionar y acceder a los datos #

# %% [raw]
# PySpark DataFrame se evalúa de forma diferida y simplemente seleccionar una columna no activa el cálculo, pero devuelve una instancia de columna.

# %%
df.a
# Out:
# Column<'a'>

# %% [raw]
# De hecho, la mayoría de las operaciones por columnas devuelven columnas.

# %%
from pyspark.sql import Column
from pyspark.sql.functions import upper

type(df.c) == type(upper(df.c)) == type(df.c.isNull())
# Out:
# True

# %% [raw]
# Estas columnas se pueden utilizar para seleccionar las columnas de un marco de datos. Por ejemplo, DataFrame.select() toma las instancias de Columna que devuelven otro DataFrame.

# %%
df.select(df.c).show()
# Out:
# +-------+
# |      c|
# +-------+
# |string1|
# |string2|
# |string3|
# +-------+

# %% [raw]
# Asigne una nueva instancia de columna.

# %%
df.withColumn('upper_c', upper(df.c)).show()
# Out:
# +---+---+-------+----------+-------------------+-------+
# |  a|  b|      c|         d|                  e|upper_c|
# +---+---+-------+----------+-------------------+-------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|STRING1|
# |  2|3.0|string2|2000-02-01|2000-01-02 12:00:00|STRING2|
# |  3|4.0|string3|2000-03-01|2000-01-03 12:00:00|STRING3|
# +---+---+-------+----------+-------------------+-------+

# %% [raw]
# Para seleccionar un subconjunto de filas, use DataFrame.filter().

# %%
df.filter(df.a == 1).show()
# Out:
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|
# +---+---+-------+----------+-------------------+

# %% [markdown]
# # Aplicando funciones #

# %% [markdown]
# PySpark admite varias UDF y API para permitir que los usuarios ejecuten funciones nativas de Python. Por ejemplo, el siguiente ejemplo permite a los usuarios usar directamente las API en una serie de pandas dentro de una función nativa de Python.

# %%
import pandas as pd
from pyspark.sql.functions import pandas_udf

# %%
@pandas_udf('long')
def pandas_plus_one(series: pd.Series) -> pd.Series:
    # Simply plus one by using pandas Series.
    return series + 1

df.select(pandas_plus_one(df.a)).show()
# Out:
# +------------------+
# |pandas_plus_one(a)|
# +------------------+
# |                 2|
# |                 3|
# |                 4|
# +------------------+

# %% [raw]
# Otro ejemplo es DataFrame.mapInPandas, que permite a los usuarios utilizar directamente las API en un DataFrame de pandas sin restricciones, como la longitud del resultado.

# %%
def pandas_filter_func(iterator):
    for pandas_df in iterator:
        yield pandas_df[pandas_df.a == 1]

df.mapInPandas(pandas_filter_func, schema=df.schema).show()
# Out:
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|
# +---+---+-------+----------+-------------------+

# %% [markdown]
# # Agrupando datos #

# %% [raw]
# PySpark DataFrame también ofrece una forma de manejar datos agrupados mediante el uso del enfoque común, la estrategia dividir-aplicar-combinar. Agrupa los datos según una determinada condición, aplica una función a cada grupo y luego los combina nuevamente en el DataFrame.

# %%
df = spark.createDataFrame([
    ['red', 'banana', 1, 10], ['blue', 'banana', 2, 20], ['red', 'carrot', 3, 30],
    ['blue', 'grape', 4, 40], ['red', 'carrot', 5, 50], ['black', 'carrot', 6, 60],
    ['red', 'banana', 7, 70], ['red', 'grape', 8, 80]], schema=['color', 'fruit', 'v1', 'v2'])
df.show()
# Out:
# +-----+------+---+---+
# |color| fruit| v1| v2|
# +-----+------+---+---+
# |  red|banana|  1| 10|
# | blue|banana|  2| 20|
# |  red|carrot|  3| 30|
# | blue| grape|  4| 40|
# |  red|carrot|  5| 50|
# |black|carrot|  6| 60|
# |  red|banana|  7| 70|
# |  red| grape|  8| 80|
# +-----+------+---+---+

# %% [raw]
# Agrupar y luego aplicar la función avg() a los grupos resultantes.

# %%
df.groupby('color').avg().show()
# Out:
# +-----+-------+-------+
# |color|avg(v1)|avg(v2)|
# +-----+-------+-------+
# |  red|    4.8|   48.0|
# | blue|    3.0|   30.0|
# |black|    6.0|   60.0|
# +-----+-------+-------+

# %% [raw]
# También puede aplicar una función nativa de Python a cada grupo utilizando la API de pandas.

# %%
def plus_mean(pandas_df):
    return pandas_df.assign(v1=pandas_df.v1 - pandas_df.v1.mean())

df.groupby('color').applyInPandas(plus_mean, schema=df.schema).show()
# Out:
# +-----+------+---+---+
# |color| fruit| v1| v2|
# +-----+------+---+---+
# |black|carrot|  0| 60|
# | blue|banana| -1| 20|
# | blue| grape|  1| 40|
# |  red|banana| -3| 10|
# |  red|carrot| -1| 30|
# |  red|carrot|  0| 50|
# |  red|banana|  2| 70|
# |  red| grape|  3| 80|
# +-----+------+---+---+

# %% [raw]
# Coagrupación y aplicación de una función.

# %%
df1 = spark.createDataFrame(
    [(20000101, 1, 1.0), (20000101, 2, 2.0), (20000102, 1, 3.0), (20000102, 2, 4.0)],
    ('time', 'id', 'v1'))

df2 = spark.createDataFrame(
    [(20000101, 1, 'x'), (20000101, 2, 'y')],
    ('time', 'id', 'v2'))

def asof_join(l, r):
    return pd.merge_asof(l, r, on='time', by='id')

df1.groupby('id').cogroup(df2.groupby('id')).applyInPandas(
    asof_join, schema='time int, id int, v1 double, v2 string').show()
# Out:
# +--------+---+---+---+
# |    time| id| v1| v2|
# +--------+---+---+---+
# |20000101|  1|1.0|  x|
# |20000102|  1|3.0|  x|
# |20000101|  2|2.0|  y|
# |20000102|  2|4.0|  y|
# +--------+---+---+---+

# %% [markdown]
# # Entrada y salida de datos #

# %% [raw]
# CSV es sencillo y fácil de usar. Parquet y ORC son formatos de archivo eficientes y compactos para leer y escribir más rápido. Hay muchas otras fuentes de datos disponibles en PySpark, como JDBC, texto, binaryFile, Avro, etc. Consulte también la última guía de Spark SQL, DataFrames y conjuntos de datos en la documentación de Apache Spark.

# %% [markdown]
# ## CSV

# %%
df.write.csv('foo.csv', header=True, mode="overwrite")
spark.read.csv('foo.csv', header=True).show()
# Out:
# +-----+------+---+---+
# |color| fruit| v1| v2|
# +-----+------+---+---+
# |black|carrot|  6| 60|
# | blue|banana|  2| 20|
# |  red|banana|  1| 10|
# |  red|carrot|  3| 30|
# | blue| grape|  4| 40|
# |  red|carrot|  5| 50|
# |  red|banana|  7| 70|
# |  red| grape|  8| 80|
# +-----+------+---+---+

# %% [markdown]
# ## PARQUET

# %%
df.write.parquet('bar.parquet', mode="overwrite")
spark.read.parquet('bar.parquet').show()
# Out:
# +-----+------+---+---+
# |color| fruit| v1| v2|
# +-----+------+---+---+
# |black|carrot|  6| 60|
# | blue|banana|  2| 20|
# | blue| grape|  4| 40|
# |  red|carrot|  5| 50|
# |  red|banana|  7| 70|
# |  red|banana|  1| 10|
# |  red|carrot|  3| 30|
# |  red| grape|  8| 80|
# +-----+------+---+---+

# %% [markdown]
# ## ORC

# %%
df.write.orc('zoo.orc', mode="overwrite")
spark.read.orc('zoo.orc').show()
# Out:
# +-----+------+---+---+
# |color| fruit| v1| v2|
# +-----+------+---+---+
# |  red|banana|  7| 70|
# |  red| grape|  8| 80|
# |black|carrot|  6| 60|
# | blue|banana|  2| 20|
# |  red|banana|  1| 10|
# |  red|carrot|  5| 50|
# |  red|carrot|  3| 30|
# | blue| grape|  4| 40|
# +-----+------+---+---+

# %% [markdown]
# # Trabajando con SQL #

# %% [raw]
# DataFrame y Spark SQL comparten el mismo motor de ejecución, por lo que pueden usarse indistintamente sin problemas. Por ejemplo, puede registrar el DataFrame como una tabla y ejecutar un SQL fácilmente como se muestra a continuación:

# %%
df.createOrReplaceTempView("tableA")
spark.sql("SELECT count(*) from tableA").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |       8|
# +--------+

# %% [raw]
# Además, las UDF se pueden registrar e invocar en SQL de forma inmediata:

# %%
@pandas_udf("integer")
def add_one(s: pd.Series) -> pd.Series:
    return s + 1

spark.udf.register("add_one", add_one)
spark.sql("SELECT add_one(v1) FROM tableA").show()
# Out:
# +-----------+
# |add_one(v1)|
# +-----------+
# |          2|
# |          3|
# |          4|
# |          5|
# |          6|
# |          7|
# |          8|
# |          9|
# +-----------+

# %% [raw]
# Estas expresiones SQL se pueden mezclar y utilizar directamente como columnas de PySpark.

# %%
from pyspark.sql.functions import expr

# %%
df.selectExpr('add_one(v1)').show()
df.select(expr('count(*)') > 0).show()
# Out:
# +-----------+
# |add_one(v1)|
# +-----------+
# |          2|
# |          3|
# |          4|
# |          5|
# |          6|
# |          7|
# |          8|
# |          9|
# +-----------+
#
# +--------------+
# |(count(1) > 0)|
# +--------------+
# |          true|
# +--------------+

# %% [markdown]
# # Inicio rápido: API de Pandas en Spark #

# %% [raw]
# Esta es una breve introducción a la API de pandas en Spark. Este cuaderno le muestra algunas diferencias clave entre pandas y la API de pandas en Spark. Habitualmente, importamos la API de pandas en Spark de la siguiente manera:

# %%
import pandas as pd
import numpy as np
import pyspark.pandas as ps
from pyspark.sql import SparkSession
# Out:
# /usr/local/spark/python/pyspark/pandas/__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(

# %% [markdown]
# * Creación de objetos:
# Crear una serie de pandas-on-Spark pasando una lista de valores, permitiendo que la API de pandas en Spark cree un índice entero predeterminado:

# %%
s = ps.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [raw]
# Crear un DataFrame de pandas-on-Spark pasando un dictado de objetos que se pueden convertir en series.

# %%
psdf = ps.DataFrame(
    {'a': [1, 2, 3, 4, 5, 6],
     'b': [100, 200, 300, 400, 500, 600],
     'c': ["one", "two", "three", "four", "five", "six"]},
    index=[10, 20, 30, 40, 50, 60])
psdf
# Out:
#     a    b      c
# 10  1  100    one
# 20  2  200    two
# 30  3  300  three
# 40  4  400   four
# 50  5  500   five
# 60  6  600    six

# %% [raw]
# Crear un DataFrame de pandas pasando una matriz numpy, con un índice de fecha y hora y columnas etiquetadas:

# %%
dates = pd.date_range('20130101', periods=6)
dates
pdf = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
pdf
# Out:
#                    A         B         C         D
# 2013-01-01 -0.367045 -0.981291 -0.614921 -0.355913
# 2013-01-02  0.932696  0.597765 -1.118993 -1.572401
# 2013-01-03  0.502658  1.212432 -1.320696 -1.080589
# 2013-01-04  1.715236 -0.442291  1.368208  0.003849
# 2013-01-05  0.214364 -0.692755  0.109878 -0.219534
# 2013-01-06  0.199766 -0.252793 -0.478801 -1.650257

# %% [raw]
# Ahora, este DataFrame de pandas se puede convertir en un DataFrame de pandas-on-Spark

# %%
psdf = ps.from_pandas(pdf)
type(psdf)
# Out:
# pyspark.pandas.frame.DataFrame

# %%
psdf
# Out:
#                    A         B         C         D
# 2013-01-01 -0.367045 -0.981291 -0.614921 -0.355913
# 2013-01-02  0.932696  0.597765 -1.118993 -1.572401
# 2013-01-03  0.502658  1.212432 -1.320696 -1.080589
# 2013-01-04  1.715236 -0.442291  1.368208  0.003849
# 2013-01-05  0.214364 -0.692755  0.109878 -0.219534
# 2013-01-06  0.199766 -0.252793 -0.478801 -1.650257

# %% [raw]
# Además, es posible crear fácilmente un DataFrame de pandas en Spark desde Spark DataFrame. Creando un Spark DataFrame a partir de pandas DataFrame

# %%
spark = SparkSession.builder.getOrCreate()
sdf = spark.createDataFrame(pdf)
sdf.show()
# Out:
# +-------------------+--------------------+-------------------+--------------------+
# |                  A|                   B|                  C|                   D|
# +-------------------+--------------------+-------------------+--------------------+
# |-0.3670450674172628| -0.9812908835215707| -0.614921046812434| -0.3559126604219527|
# | 0.9326960462136177|  0.5977648837464683|-1.1189928439823946| -1.5724007302316794|
# | 0.5026584753394927|   1.212432468720428|-1.3206957611282975| -1.0805892263550108|
# | 1.7152364140076737|-0.44229109378871406| 1.3682082775139146|0.003848997723393...|
# |0.21436408706448984| -0.6927545467684585|0.10987753374800197| -0.2195343036626632|
# |0.19976564696501145|-0.25279272444539885|-0.4788014831156336| -1.6502566791648736|
# +-------------------+--------------------+-------------------+--------------------+

# %% [raw]
# Creando pandas-on-Spark DataFrame desde Spark DataFrame.

# %%
psdf = sdf.pandas_api()
psdf
# Out:
#           A         B         C         D
# 0 -0.367045 -0.981291 -0.614921 -0.355913
# 1  0.932696  0.597765 -1.118993 -1.572401
# 2  0.502658  1.212432 -1.320696 -1.080589
# 3  1.715236 -0.442291  1.368208  0.003849
# 4  0.214364 -0.692755  0.109878 -0.219534
# 5  0.199766 -0.252793 -0.478801 -1.650257

# %% [raw]
# Actualmente se admiten tipos que son comunes tanto para Spark como para pandas.

# %%
psdf.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %% [raw]
# Aquí se muestra cómo mostrar las filas superiores del marco que se muestra a continuación. Tenga en cuenta que los datos en un marco de datos de Spark no conservan el orden natural de forma predeterminada. El orden natural se puede conservar configurando la opción calculate.ordered_head, pero esto genera una sobrecarga de rendimiento con la ordenación interna.

# %%
psdf.head()
# Out:
#           A         B         C         D
# 0 -0.367045 -0.981291 -0.614921 -0.355913
# 1  0.932696  0.597765 -1.118993 -1.572401
# 2  0.502658  1.212432 -1.320696 -1.080589
# 3  1.715236 -0.442291  1.368208  0.003849
# 4  0.214364 -0.692755  0.109878 -0.219534

# %% [raw]
# Mostrando el índice, las columnas y los numerosos datos subyacentes.

# %%
psdf.index
# Out:
# Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
psdf.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
psdf.to_numpy()
# Out:
# /usr/local/spark/python/pyspark/pandas/utils.py:1016: PandasAPIOnSparkAdviceWarning: `to_numpy` loads all data into the driver's memory. It should only be used if the resulting NumPy ndarray is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)
# array([[-0.36704507, -0.98129088, -0.61492105, -0.35591266],
#        [ 0.93269605,  0.59776488, -1.11899284, -1.57240073],
#        [ 0.50265848,  1.21243247, -1.32069576, -1.08058923],
#        [ 1.71523641, -0.44229109,  1.36820828,  0.003849  ],
#        [ 0.21436409, -0.69275455,  0.10987753, -0.2195343 ],
#        [ 0.19976565, -0.25279272, -0.47880148, -1.65025668]])

# %% [raw]
# Mostrar un resumen estadístico rápido de sus datos

# %%
psdf.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.532946 -0.093155 -0.342554 -0.812474
# std    0.718473  0.833980  0.978138  0.718006
# min   -0.367045 -0.981291 -1.320696 -1.650257
# 25%    0.199766 -0.692755 -1.118993 -1.572401
# 50%    0.214364 -0.442291 -0.614921 -1.080589
# 75%    0.932696  0.597765  0.109878 -0.219534
# max    1.715236  1.212432  1.368208  0.003849

# %% [raw]
# Transponiendo sus datos

# %%
psdf.T
# Out:
#           0         1         2         3         4         5
# A -0.367045  0.932696  0.502658  1.715236  0.214364  0.199766
# B -0.981291  0.597765  1.212432 -0.442291 -0.692755 -0.252793
# C -0.614921 -1.118993 -1.320696  1.368208  0.109878 -0.478801
# D -0.355913 -1.572401 -1.080589  0.003849 -0.219534 -1.650257

# %% [raw]
# Ordenando por su índice

# %%
psdf.sort_index(ascending=False)
# Out:
#           A         B         C         D
# 5  0.199766 -0.252793 -0.478801 -1.650257
# 4  0.214364 -0.692755  0.109878 -0.219534
# 3  1.715236 -0.442291  1.368208  0.003849
# 2  0.502658  1.212432 -1.320696 -1.080589
# 1  0.932696  0.597765 -1.118993 -1.572401
# 0 -0.367045 -0.981291 -0.614921 -0.355913

# %% [raw]
# Ordenar por valor

# %%
psdf.sort_values(by='B')
# Out:
#           A         B         C         D
# 0 -0.367045 -0.981291 -0.614921 -0.355913
# 4  0.214364 -0.692755  0.109878 -0.219534
# 3  1.715236 -0.442291  1.368208  0.003849
# 5  0.199766 -0.252793 -0.478801 -1.650257
# 1  0.932696  0.597765 -1.118993 -1.572401
# 2  0.502658  1.212432 -1.320696 -1.080589

# %% [markdown]
# # Datos faltantes #

# %% [raw]
# La API de Pandas en Spark utiliza principalmente el valor np.nan para representar los datos faltantes. Por defecto no se incluye en los cálculos.

# %%
pdf1 = pdf.reindex(index=dates[0:4], columns=list(pdf.columns) + ['E'])
pdf1.loc[dates[0]:dates[1], 'E'] = 1
psdf1 = ps.from_pandas(pdf1)
psdf1
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.367045 -0.981291 -0.614921 -0.355913  1.0
# 2013-01-02  0.932696  0.597765 -1.118993 -1.572401  1.0
# 2013-01-03  0.502658  1.212432 -1.320696 -1.080589  NaN
# 2013-01-04  1.715236 -0.442291  1.368208  0.003849  NaN

# %% [raw]
# Para eliminar cualquier fila a la que le falten datos.

# %%
psdf1.dropna(how='any')
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.367045 -0.981291 -0.614921 -0.355913  1.0
# 2013-01-02  0.932696  0.597765 -1.118993 -1.572401  1.0

# %% [raw]
# Llenando datos faltantes.

# %%
psdf1.fillna(value=5)
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.367045 -0.981291 -0.614921 -0.355913  1.0
# 2013-01-02  0.932696  0.597765 -1.118993 -1.572401  1.0
# 2013-01-03  0.502658  1.212432 -1.320696 -1.080589  5.0
# 2013-01-04  1.715236 -0.442291  1.368208  0.003849  5.0

# %% [markdown]
# # Operacioness

# %% [markdown]
# ## Estadística

# %% [raw]
# Realizando una estadística descriptiva:

# %%
psdf.mean()
# Out:
# A    0.532946
# B   -0.093155
# C   -0.342554
# D   -0.812474
# dtype: float64

# %% [markdown]
# ## Configuraciones de Spark

# %% [raw]
# Se pueden aplicar varias configuraciones en PySpark de forma interna en la API de Pandas en Spark. Por ejemplo, puede habilitar la optimización de Arrow para acelerar enormemente la conversión interna de Pandas.

# %%
prev = spark.conf.get("spark.sql.execution.arrow.pyspark.enabled")  # Keep its default value.
ps.set_option("compute.default_index_type", "distributed")  # Use default index prevent overhead.
import warnings
warnings.filterwarnings("ignore")  # Ignore warnings coming from Arrow optimizations.

# %%
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", True)
# %timeit ps.range(300000).to_pandas()
# Out:
# 228 ms ± 26.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", False)
# %timeit ps.range(300000).to_pandas()
# Out:
# 1.19 s ± 127 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
ps.reset_option("compute.default_index_type")
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", prev)  # Set its default value back.

# %% [markdown]
# # Agrupaciones

# %% [raw]
# Por “agrupar por” nos referimos a un proceso que involucra uno o más de los siguientes pasos:
# - Dividir los datos en grupos según algunos criterios.
# - Aplicar una función a cada grupo de forma independiente
# - Combinar los resultados en una estructura de datos.

# %%
psdf = ps.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                    'B': ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                    'C': np.random.randn(8),
                    'D': np.random.randn(8)})
psdf
# Out:
#      A      B         C         D
# 0  foo    one -0.479530  1.214565
# 1  bar    one -0.248678  0.852322
# 2  foo    two  0.064281  1.790076
# 3  bar  three  0.895084  2.698925
# 4  foo    two -0.760154  0.824861
# 5  bar    two -0.186017 -1.178444
# 6  foo    one  0.538806  1.400224
# 7  foo  three -0.706009  0.240852

# %% [raw]
# Agrupar y luego aplicar la función sum() a los grupos resultantes.

# %%
psdf.groupby('A').sum()
# Out:
#             C         D
# A
# foo -1.342606  5.470578
# bar  0.460389  2.372802

# %% [raw]
# La agrupación por varias columnas forma un índice jerárquico y nuevamente podemos aplicar la función de suma.

# %%
psdf.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# foo one    0.059276  2.614789
# bar one   -0.248678  0.852322
# foo two   -0.695872  2.614937
# bar three  0.895084  2.698925
#     two   -0.186017 -1.178444
# foo three -0.706009  0.240852

# %% [markdown]
# # Graficación

# %%
pip install plotly==5.23.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 5.9 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pser = pd.Series(np.random.randn(1000),
                 index=pd.date_range('1/1/2000', periods=1000))

# %%
psser = ps.Series(pser)

# %%
psser = psser.cummax()

# %%
psser.plot()
# Out:
# <div>                            <div id="bbc94ceb-7ef9-4fb2-bdc1-715e8cb22f1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbc94ceb-7ef9-4fb2-bdc1-715e8cb22f1a")) {                    Plotly.newPlot(                        "bbc94ceb-7ef9-4fb2-bdc1-715e8cb22f1a",                        [{"hovertemplate":"variable=0\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","orientation":"v","showlegend":true,"x":["2000-01-01T00:00:00","2000-01-02T00:00:00","2000-01-03T00:00:00","2000-01-04T00:00:00","2000-01-05T00:00:00","2000-01-06T00:00:00","2000-01-07T00:00:00","2000-01-08T00:00:00","2000-01-09T00:00
# ...

# %% [raw]
# En un DataFrame, el método plot() es conveniente para trazar todas las columnas con etiquetas:

# %%
pdf = pd.DataFrame(np.random.randn(1000, 4), index=pser.index,
                   columns=['A', 'B', 'C', 'D'])
psdf = ps.from_pandas(pdf)
psdf = psdf.cummax()
psdf.plot()
# Out:
# <div>                            <div id="dd1986f5-fcf0-47f3-a977-7c51f9b91e43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd1986f5-fcf0-47f3-a977-7c51f9b91e43")) {                    Plotly.newPlot(                        "dd1986f5-fcf0-47f3-a977-7c51f9b91e43",                        [{"hovertemplate":"variable=A\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"A","showlegend":true,"x":["2000-01-01T00:00:00","2000-01-02T00:00:00","2000-01-03T00:00:00","2000-01-04T00:00:00","2000-01-05T00:00:00","2000-01-06T00:00:00","2000-01-07T00:00:00","2000-01-08T00:00:00","2000-01-09T00:00:00","2000-01-10T0
# ...

# %% [markdown]
# # Entrada y salida de datos

# %% [markdown]
# ## CSV.

# %%
psdf.to_csv('foo.csv')
ps.read_csv('foo.csv').head(10)
# Out:
#           A         B         C         D
# 0  0.114543  0.425051  1.499162  0.668994
# 1  0.114543  0.425051  1.499162  1.421866
# 2  0.114543  0.425051  1.499162  1.421866
# 3  0.752672  0.425051  1.499162  1.421866
# 4  0.752672  0.425051  1.499162  1.619868
# 5  0.752672  1.031866  1.499162  1.619868
# 6  1.252836  2.187150  1.499162  1.619868
# 7  1.252836  2.187150  1.499162  1.619868
# 8  1.252836  2.187150  1.857040  1.619868
# 9  1.252836  2.187150  1.857040  1.619868

# %% [markdown]
# ## Parquet

# %%
psdf.to_parquet('bar.parquet')
ps.read_parquet('bar.parquet').head(10)
# Out:
#           A         B         C         D
# 0  0.114543  0.425051  1.499162  0.668994
# 1  0.114543  0.425051  1.499162  1.421866
# 2  0.114543  0.425051  1.499162  1.421866
# 3  0.752672  0.425051  1.499162  1.421866
# 4  0.752672  0.425051  1.499162  1.619868
# 5  0.752672  1.031866  1.499162  1.619868
# 6  1.252836  2.187150  1.499162  1.619868
# 7  1.252836  2.187150  1.499162  1.619868
# 8  1.252836  2.187150  1.857040  1.619868
# 9  1.252836  2.187150  1.857040  1.619868

# %% [markdown]
# ## Spark IO

# %% [raw]
# Además, la API de pandas en Spark es totalmente compatible con las diversas fuentes de datos de Spark, como ORC y una fuente de datos externa.

# %%
psdf.to_spark_io('zoo.orc', format="orc")
ps.read_spark_io('zoo.orc', format="orc").head(10)
# Out:
#           A         B         C         D
# 0  0.114543  0.425051  1.499162  0.668994
# 1  0.114543  0.425051  1.499162  1.421866
# 2  0.114543  0.425051  1.499162  1.421866
# 3  0.752672  0.425051  1.499162  1.421866
# 4  0.752672  0.425051  1.499162  1.619868
# 5  0.752672  1.031866  1.499162  1.619868
# 6  1.252836  2.187150  1.499162  1.619868
# 7  1.252836  2.187150  1.499162  1.619868
# 8  1.252836  2.187150  1.857040  1.619868
# 9  1.252836  2.187150  1.857040  1.619868

# %% [markdown]
# Fuente: https://spark.apache.org/docs/3.3.1/api/python/getting_started/install.html
